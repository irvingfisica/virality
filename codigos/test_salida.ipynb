# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../codigos/Calificacion_temas/outputs/salida_CDMX.csv")

# %%
len(data[data["Calificacion"]<10])/len(data)*100
# Out:
# 55.81931089743589

# %%
np.histogram(data["Calificacion"],bins=100)
# Out:
# (array([1344,  777,  630,  548,  482,  423,  392,  357,  314,  311,  272,
#          252,  235,  227,  191,  204,  176,  166,  160,  144,  138,  124,
#          120,  116,  103,  105,   90,   87,   85,   84,   70,   69,   63,
#           71,   54,   50,   51,   54,   44,   43,   37,   43,   36,   28,
#           34,   29,   36,   26,   22,   25,   26,   18,   21,   17,   21,
#           17,   21,   17,   21,   11,   12,    9,   13,   14,   12,   13,
#           11,   15,   10,    8,    7,    7,    4,    5,    2,    5,    2,
#           22,   21,   15,    7,    5,   10,    3,    3,    3,    1,    3,
#            1,    3,    0,    0,    2,    2,    0,    0,    0,    1,    0,
#            1], dtype=int64),
#  array([2.42524605e-02, 1.02400994e+00, 2.02376741e+00, 3.02352489e+00,
#         4.02328236e+00, 5.02303984e+00, 6.02279731e+00, 7.02255479e+00,
#         8.02231226e+00, 9.02206974e+00, 1.00218272e+01, 1.10215847e+01,
# ...
